# %% [markdown]
# # Importing necessary Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout,Conv2D,Flatten,MaxPool2D,Reshape,InputLayer
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # Data Augumentation
#
# * Dataset consist of 5 classes.
# * **Daisy** - European Species of Aster family.
# * **Sunflower** - Identified as the genus of Helianthus.
# * **Tulip** - Belong to the species of spring blooming geophytes.
# * **Rose** - Belongs to the family of rosaceae.
# * **Dandelion** - Indentifies as the genus of Asterceae.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Flowers'

# %%
train_data_gen = ImageDataGenerator(rescale = 1./255,
                             shear_range = 0.2,
                             zoom_range = 0.2,
                             horizontal_flip = True,
                             validation_split = 0.30)
test_data_gen = ImageDataGenerator(rescale = 1./255,validation_split = 0.30)

# %%
training_set = train_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'training')

testing_set = test_data_gen.flow_from_directory(path,
                                                 target_size=(64,64),
                                                 batch_size=100,
                                                 class_mode='categorical',
                                                 shuffle=True,
                                                 color_mode='rgb',
                                                 subset = 'validation')
# Out:
# Found 3041 images belonging to 5 classes.
# Found 1300 images belonging to 5 classes.

# %% [markdown]
# # Model building using CNN
# **1. Create the model**

# %%
model = Sequential()

#convolution and Pooling layer 1
model.add(Conv2D(filters=48,kernel_size=3,activation='relu',input_shape=(64,64,3)))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#convolution and Pooling layer 2
model.add(Conv2D(filters=32,kernel_size=3,activation='relu'))
model.add(MaxPool2D(pool_size=2,strides=2))
model.add(Dropout(0.2))

#Flattening the images
model.add(Flatten())

#Fully Connected layers
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 48)        1344
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 48)       0
#  )
#
#  dropout (Dropout)           (None, 31, 31, 48)        0
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        13856
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 64)                401472
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 416,997
# Trainable params: 416,997
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **2. Compile the Model**

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# **3. Adding callbacks to avoid overfitting**

# %%
early_stop = EarlyStopping(monitor='val_accuracy', 
                           patience=5,verbose=1,mode='auto')

lr = ReduceLROnPlateau(monitor='val_accuracy', 
                       factor=0.2,patience=5, 
                       min_lr=0.00001)

callback = [early_stop,lr]

# %% [markdown]
# **4. Training the Model**

# %%
result = model.fit(x=training_set, validation_data=testing_set, epochs=50)
# Out:
# Epoch 1/50
# 31/31 [==============================] - 1084s 35s/step - loss: 1.4227 - accuracy: 0.3716 - val_loss: 1.3010 - val_accuracy: 0.4285
# Epoch 2/50
# 31/31 [==============================] - 39s 1s/step - loss: 1.2367 - accuracy: 0.4594 - val_loss: 1.1979 - val_accuracy: 0.5146
# Epoch 3/50
# 31/31 [==============================] - 38s 1s/step - loss: 1.1444 - accuracy: 0.5199 - val_loss: 1.2197 - val_accuracy: 0.4900
# Epoch 4/50
# 31/31 [==============================] - 39s 1s/step - loss: 1.1021 - accuracy: 0.5488 - val_loss: 1.1195 - val_accuracy: 0.5792
# Epoch 5/50
# 31/31 [==============================] - 39s 1s/step - loss: 1.0651 - accuracy: 0.5774 - val_loss: 1.0784 - val_accuracy: 0.5785
# Epoch 6/50
# 31/31 [==============================] - 39s 1s/step - loss: 1.0377 - accuracy: 0.5906 - val_loss: 1.0662 - val_accuracy: 0.5777
# Epoch 7/50
# 31/31 [==============================] - 38s 1s/step - loss: 1.0027 - accuracy: 0.5995 - val_loss: 1.0649 - val_accuracy: 0.5746
# Epoch 8/50
# 31/31 [==============================] - 40s 1s/step - loss: 0.9547 - accuracy: 0.6228 - val_loss: 1.0267 - val_accuracy: 0.5977
# Epoch 9/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.9261 - accuracy: 0.6324 - val_loss: 1.0120 - val_accuracy: 0.6054
# Epoch 10/50
# 31/31 [==============================] - 38s 1s/step - loss: 0.9089 - accuracy: 0.6442 - val_loss: 1.0281 - val_accuracy: 0.6085
# Epoch 11/50
# 31/31 [==============================] - 41s 1s/step - loss: 0.8640 - accuracy: 0.6689 - val_loss: 0.9979 - val_accuracy: 0.6300
# Epoch 12/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.8629 - accuracy: 0.6610 - val_loss: 0.9367 - val_accuracy: 0.6538
# Epoch 13/50
# 31/31 [==============================] - 41s 1s/step - loss: 0.8464 - accuracy: 0.6708 - val_loss: 0.9676 - val_accuracy: 0.6262
# Epoch 14/50
# 31/31 [==============================] - 38s 1s/step - loss: 0.8219 - accuracy: 0.6754 - val_loss: 0.9526 - val_accuracy: 0.6223
# Epoch 15/50
# 31/31 [==============================] - 38s 1s/step - loss: 0.8069 - accuracy: 0.6761 - val_loss: 0.9247 - val_accuracy: 0.6431
# Epoch 16/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.7904 - accuracy: 0.6892 - val_loss: 0.9939 - val_accuracy: 0.6308
# Epoch 17/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.7578 - accuracy: 0.7024 - val_loss: 0.9895 - val_accuracy: 0.6423
# Epoch 18/50
# 31/31 [==============================] - 38s 1s/step - loss: 0.7679 - accuracy: 0.7027 - val_loss: 1.0640 - val_accuracy: 0.6277
# Epoch 19/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.7971 - accuracy: 0.6797 - val_loss: 0.9387 - val_accuracy: 0.6354
# Epoch 20/50
# 31/31 [==============================] - 38s 1s/step - loss: 0.7453 - accuracy: 0.7096 - val_loss: 0.9480 - val_accuracy: 0.6423
# Epoch 21/50
# 31/31 [==============================] - 41s 1s/step - loss: 0.7383 - accuracy: 0.7054 - val_loss: 0.9458 - val_accuracy: 0.6546
# Epoch 22/50
# 31/31 [==============================] - 41s 1s/step - loss: 0.7051 - accuracy: 0.7208 - val_loss: 0.9819 - val_accuracy: 0.6585
# Epoch 23/50
# 31/31 [==============================] - 41s 1s/step - loss: 0.6995 - accuracy: 0.7294 - val_loss: 0.9713 - val_accuracy: 0.6469
# Epoch 24/50
# 31/31 [==============================] - 41s 1s/step - loss: 0.6828 - accuracy: 0.7396 - val_loss: 0.9269 - val_accuracy: 0.6685
# Epoch 25/50
# 31/31 [==============================] - 41s 1s/step - loss: 0.6690 - accuracy: 0.7442 - val_loss: 0.8777 - val_accuracy: 0.6769
# Epoch 26/50
# 31/31 [==============================] - 43s 1s/step - loss: 0.6658 - accuracy: 0.7373 - val_loss: 0.9391 - val_accuracy: 0.6800
# Epoch 27/50
# 31/31 [==============================] - 42s 1s/step - loss: 0.6492 - accuracy: 0.7567 - val_loss: 0.8834 - val_accuracy: 0.6738
# Epoch 28/50
# 31/31 [==============================] - 40s 1s/step - loss: 0.6415 - accuracy: 0.7491 - val_loss: 0.9993 - val_accuracy: 0.6546
# Epoch 29/50
# 31/31 [==============================] - 38s 1s/step - loss: 0.6405 - accuracy: 0.7507 - val_loss: 0.9746 - val_accuracy: 0.6546
# Epoch 30/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.6285 - accuracy: 0.7590 - val_loss: 0.9058 - val_accuracy: 0.6777
# Epoch 31/50
# 31/31 [==============================] - 38s 1s/step - loss: 0.6153 - accuracy: 0.7646 - val_loss: 0.9512 - val_accuracy: 0.6677
# Epoch 32/50
# 31/31 [==============================] - 40s 1s/step - loss: 0.6292 - accuracy: 0.7599 - val_loss: 0.9043 - val_accuracy: 0.6638
# Epoch 33/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.6137 - accuracy: 0.7665 - val_loss: 0.9405 - val_accuracy: 0.6754
# Epoch 34/50
# 31/31 [==============================] - 38s 1s/step - loss: 0.5679 - accuracy: 0.7840 - val_loss: 0.8869 - val_accuracy: 0.6831
# Epoch 35/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.6090 - accuracy: 0.7642 - val_loss: 0.9448 - val_accuracy: 0.6531
# Epoch 36/50
# 31/31 [==============================] - 38s 1s/step - loss: 0.5983 - accuracy: 0.7764 - val_loss: 0.8868 - val_accuracy: 0.6785
# Epoch 37/50
# 31/31 [==============================] - 38s 1s/step - loss: 0.5692 - accuracy: 0.7830 - val_loss: 0.9187 - val_accuracy: 0.6785
# Epoch 38/50
# 31/31 [==============================] - 38s 1s/step - loss: 0.5722 - accuracy: 0.7780 - val_loss: 0.9634 - val_accuracy: 0.6646
# Epoch 39/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.5589 - accuracy: 0.7793 - val_loss: 0.8984 - val_accuracy: 0.6769
# Epoch 40/50
# 31/31 [==============================] - 41s 1s/step - loss: 0.5285 - accuracy: 0.7958 - val_loss: 0.9287 - val_accuracy: 0.6769
# Epoch 41/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.5278 - accuracy: 0.7988 - val_loss: 0.9578 - val_accuracy: 0.6715
# Epoch 42/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.5306 - accuracy: 0.7981 - val_loss: 0.9524 - val_accuracy: 0.6815
# Epoch 43/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.5131 - accuracy: 0.8083 - val_loss: 0.9569 - val_accuracy: 0.6792
# Epoch 44/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.5193 - accuracy: 0.8083 - val_loss: 1.0133 - val_accuracy: 0.6862
# Epoch 45/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.4936 - accuracy: 0.8093 - val_loss: 1.0149 - val_accuracy: 0.6823
# Epoch 46/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.4807 - accuracy: 0.8195 - val_loss: 0.9777 - val_accuracy: 0.6900
# Epoch 47/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.4742 - accuracy: 0.8182 - val_loss: 0.9516 - val_accuracy: 0.6838
# Epoch 48/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.4874 - accuracy: 0.8135 - val_loss: 0.9800 - val_accuracy: 0.6838
# Epoch 49/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.4674 - accuracy: 0.8208 - val_loss: 1.0827 - val_accuracy: 0.6662
# Epoch 50/50
# 31/31 [==============================] - 39s 1s/step - loss: 0.4647 - accuracy: 0.8224 - val_loss: 0.9746 - val_accuracy: 0.6777

# %% [markdown]
# **5. Loss and Accuracy check using plot**

# %%
#plot the loss
plt.plot(result.history['loss'], label='train loss')
plt.plot(result.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(result.history['accuracy'], label='train acc')
plt.plot(result.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %% [markdown]
# **6. Save the Model**

# %%
model.save('flower.h5')

# %% [markdown]
# # Testing the Model

# %%
training_set.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
classes = ['Daisy','Dandelion','Rose','Sunflower','Tulip'] 
def testing(img):
    img = image.load_img(img,target_size=(64,64)) 
    x = image.img_to_array(img) 
    x = np.expand_dims(x,axis=0) 
    pred = np.argmax(model.predict(x)) 
    return print("Predicted class as:",classes[pred])

def img_show(img):
    img1 = image.load_img(img,target_size=(64,64)) 
    plt.imshow(img1)

# %%
#test1
img_show('/content/drive/MyDrive/Colab Notebooks/Flowers/daisy/10172379554_b296050f82_n.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/Flowers/daisy/10172379554_b296050f82_n.jpg')
# Out:
# Predicted class as: Daisy

# %%
#test2
img_show('/content/drive/MyDrive/Colab Notebooks/Flowers/rose/118974357_0faa23cce9_n.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/Flowers/rose/12338444334_72fcc2fc58_m.jpg')
# Out:
# Predicted class as: Rose

# %%
#test3
img_show('/content/drive/MyDrive/Colab Notebooks/Flowers/sunflower/10386503264_e05387e1f7_m.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/Flowers/sunflower/10386503264_e05387e1f7_m.jpg')
# Out:
# Predicted class as: Sunflower

# %%
#test4
img_show('/content/drive/MyDrive/Colab Notebooks/Flowers/tulip/10128546863_8de70c610d.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/Flowers/tulip/10128546863_8de70c610d.jpg')
# Out:
# Predicted class as: Tulip

# %%
#test5
img_show('/content/drive/MyDrive/Colab Notebooks/Flowers/dandelion/6.jpg')
testing('/content/drive/MyDrive/Colab Notebooks/Flowers/dandelion/6.jpg')
# Out:
# Predicted class as: Dandelion

# %% [markdown]
# # Conclusion:
# * The dataset has about 4317 images from 5 different classes.
# * Each classes have more than 500 images for training the data.
# * 30% of the data taken for validation.
# * The accuracy of the model is around 80%.
# * The validation accuracy is around 70%.
# * The model is built with 2 layered convolutional network considering 1344 trainable parameters.
# * Testing the model with unknown images gives 95% accuracy.
